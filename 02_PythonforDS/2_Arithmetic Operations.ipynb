# %%
a=10
b=2
print(a**b)
print(a/b)
print(a-b)
print(a//b)
print(a%b) # Modulus/Reminder
print(11%3)
# Out:
# 100
# 5.0
# 8
# 5
# 0
# 2

# %%
import math
a = 7/3
print(a)
print(math.floor(a))
print(math.ceil(a))
# Out:
# 2.3333333333333335
# 2
# 3

# %%
# BODMAS

print((4*5)-9+6/7)
# Out:
# 11.857142857142858

# %%
(4*5)
# Out:
# 20

# %%
6/7
# Out:
# 0.8571428571428571

# %%
print(4+(8**2)-3**2%1)
# Out:
# 68

# %%
9%1
# Out:
# 0

# %%
print(4 % (1 + 9)**2 - 60 // (7 + 2))
# Out:
# -2

# %%
9%1
# Out:
# 0

# %%
60//7
# Out:
# 8

# %%
60%7
# Out:
# 4

# %%
3**3
# Out:
# 27

# %%
3**4
# Out:
# 81

# %%
floor: 8
ceiling: 9

# %%
2+5
# Out:
# 7

# %%
2-5
# Out:
# -3

# %%
2*5
# Out:
# 10

# %%
2/5
# Out:
# 0.4
