# %% [markdown]
# ## <span style=color:cornflowerblue><b> Datatypes</b></span>

# %% [markdown]
# <span style=color:orange><b>
# String
# </b></span>

# %%
a='hello world'
print(type(a))
print(a)
# Out:
# <class 'str'>
# hello world

# %% [markdown]
# <span style=color:orange><b>
# Int
# </b></span>

# %%
my_age = 31
print(my_age)
print(type(my_age))
# Out:
# 31
# <class 'int'>

# %% [markdown]
# <span style=color:orange><b>
# Float
# </b></span>

# %%
score = 89.996778
print(score)
print(type(score))
# Out:
# 89.996778
# <class 'float'>

# %% [markdown]
# <span style=color:orange><b>
# Boolean
# </b></span>

# %%
a=True
print(type(a))
print(a)
# Out:
# <class 'bool'>
# True

# %% [markdown]
# <span style=color:orange><b>
# Typecasting
# </b></span>

# %%
a = '10.5'
print(a) #not int or float
print(type(a))
a='True'
print(type(a))  # not bollean
print(a)
# Out:
# 10.5
# <class 'str'>
# <class 'str'>
# True

# %%
#changing types
var = 2
print(type(var))
var1 = float(var)
print(type(var1))
print(var1)
# Out:
# <class 'int'>
# <class 'float'>
# 2.0

# %%
var = 2.9
var_int = int(var)
print(var_int)
# Out:
# 2

# %%
# Convert a float value inside a string variable to Integer
string_var = "2.5"
#int(string_var) will give error as underlying is float
int(float("2.5"))
# Out:
# 2

# %% [markdown]
# <span style=color:orange><b>
# String immutability
# - We can access string using index
# - But using same index we can't modify
# </b></span>

# %%
s = "AMIT"
print(s[0])
print(s[-1])
#s[0] = a;      #not allowed will throw exception
# Out:
# A
# T

# %% [markdown]
# <span style=color:orange><b>
# Byte
# - Given a variable of type bytes how do convert it to string, given if I don't know which encoding decoding was used for byte?
# - Answer you can't
# </b></span>

# %%
s = 'abcd'  #Latin included in ASCII so take 1 byte per charector
print(len(s))
 #lets take hebrew now
s = 'שלום' #Hebrew Arabic Russian Greek even special charector in English take 2 byte
print(len(s))
# Out:
# 4
# 4

# %% [markdown]
# <span style=color:orange><b>
# - Unicode --> Lest assign a a unique number to every charector ever created and it will be represented using UTF-8
# - UTF-* means, if its ASCII it will take 1 byte, for Hebre, Russian Greek 2 bytes, chenese Japnese 3 bytes and emojis
# </b></span>

# %%
#b = bytes('abc') # won't work without mentioning encoding
b = bytes('abc', encoding='utf-8')
print(b)
#or
b = b'abc'
print(type(b))
print(b[0])
# Out:
# b'abc'
# <class 'bytes'>
# 97

# %% [markdown]
# <span style=color:orange><b>
# - So while converting byte and String we must mention encoding otherwise won't make much sence to python
# </b></span>

# %%
s = 'שלום'
b = bytes(s, encoding='utf-8')
print(b)
#Simillarly to convert back to string
s = str(b, encoding='utf-8')
print(s)
s = str(b, encoding='latin-1')
print(s)  #wrong output


#byte string  like String are immutable
s = 'abcd'
# s[0] = 'r'  #can't do
b =b'abcd'
# b[0] ='65'  #can't do
# Out:
# b'\xd7\xa9\xd7\x9c\xd7\x95\xd7\x9d'
# שלום
# ×©×××
